# %%
import sys
sys.path.append("/home/stylianos/Desktop/GIT/MDML/src/")

# %%
from mdml.Pipeline import preprocess, ML, mapping

# %%
preprocess('/home/stylianos/Desktop/config.yml')
# Out:
# Loading trajecrories...
# Found 2 trajectories:
# ParseTrajectory(name=inactive, universe=(326, 3))
# /home/stylianos/MLMD/lib/python3.8/site-packages/MDAnalysis/topology/PDBParser.py:345: UserWarning: Unknown element  found for some atoms. These have been given an empty element record. If needed they can be guessed using MDAnalysis.topology.guessers.
#   warnings.warn(wmsg)
# /home/stylianos/MLMD/lib/python3.8/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types:
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# WARNING: Unable to index full trajectory for 1650 images, excluded first 1 frames
# ParseTrajectory(name=active, universe=(326, 3))
# WARNING: Unable to index full trajectory for 1650 images, excluded first 1 frames

# %%
ML('/home/stylianos/Desktop/config.yml')
# Out:
# Loading data...
# Found 2640 images belonging to 2 classes.
# Found 660 images belonging to 2 classes.
# 2023-03-06 14:10:29.992626: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/stylianos/MLMD/lib/python3.8/site-packages/cv2/../../lib64:
# 2023-03-06 14:10:29.992658: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# ...

# %%
mapping('/home/stylianos/Desktop/config.yml')
# Out:
# /home/stylianos/MLMD/lib/python3.8/site-packages/MDAnalysis/topology/PDBParser.py:345: UserWarning: Unknown element  found for some atoms. These have been given an empty element record. If needed they can be guessed using MDAnalysis.topology.guessers.
#   warnings.warn(wmsg)
# /home/stylianos/MLMD/lib/python3.8/site-packages/MDAnalysis/topology/guessers.py:146: UserWarning: Failed to guess the mass for the following atom types:
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# 2023-03-06 14:20:10.817857: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/stylianos/MLMD/lib/python3.8/site-packages/cv2/../../lib64:
# ...
